# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

t = 1.0e-5

count_words = Counter(int_words)
num_words = len(int_words)
proba_words = {word: 1.0 - np.sqrt(t / float(ct) * float(num_words)) for word, ct in count_words.items()}

train_words = [word for word in int_words if random.random() < 1.0 - proba_words[word]]
print (len(train_words))
# Out:
# 4625999

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size + 1)
    start = max(0, idx - R)
    end = min(len(words)-1, idx + R + 1)
    label_words = words[start : idx] + words[idx + 1 : end]
    
    return list(label_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-20-0edb403d10d5>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7257 0.4660 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6544 0.4533 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5536 0.4529 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6505 0.4602 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5931 0.4566 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5828 0.4645 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5863 0.4520 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6130 0.4524 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5466 0.4396 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4988 0.4418 sec/batch
# Nearest to between: unlike, receding, sleep, disavowed, feud, siege, massilia, woo,
# Nearest to has: obtainable, playfulness, radiation, ratiocinator, donors, misandry, remembered, cracow,
# Nearest to there: pay, unarable, afro, junction, release, qam, loy, wittelsbach,
# Nearest to i: canadian, reductionist, dreadnought, romp, drags, install, ruach, lp,
# Nearest to these: springer, coral, intra, cupboard, tails, thereby, bugsy, isomorphism,
# Nearest to often: girona, gherkin, targeting, terribly, manure, kyiv, crates, prum,
# Nearest to are: bancroft, evident, fabio, hikaru, segments, marmara, kroq, axioms,
# Nearest to however: gottlieb, implied, doughnuts, update, asks, gentiles, successive, topological,
# Nearest to writers: mchenry, bituminous, petrified, xiv, comoros, georgians, projekt, venue,
# Nearest to ice: assorted, bubblegum, dik, disloyal, costas, ac, dissolved, andromache,
# Nearest to derived: faisal, ece, reworking, nm, dignity, pied, recaptured, bishkek,
# Nearest to account: sup, technicality, straightforward, jade, cellist, leroux, bhutto, columnist,
# Nearest to construction: wilfrid, cymru, hammerhead, puppeteer, sdi, demosthenes, played, virchow,
# Nearest to nobel: err, aasen, anyone, functionalists, minden, other, flowered, oued,
# Nearest to professional: lusignan, lazio, amphibole, main, carved, transcriptions, transferable, gained,
# Nearest to grand: yellow, viscounts, macintoshes, enhanced, kentucky, ambrosia, kurukshetra, downloaded,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5024 0.4507 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4523 0.4717 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3877 0.4504 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2867 0.4638 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2394 0.4484 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2287 0.4464 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1567 0.4656 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1267 0.4734 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0903 0.4488 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0560 0.4443 sec/batch
# Nearest to between: unlike, sleep, material, describes, feud, receding, pension, siege,
# Nearest to has: english, obtainable, remembered, playfulness, radiation, facts, donors, ratiocinator,
# Nearest to there: pay, release, junction, paris, collect, unarable, afro, ewen,
# Nearest to i: canadian, trio, reductionist, remaining, romp, lp, dreadnought, card,
# Nearest to these: springer, thereby, permanently, extinct, tails, coral, description, intra,
# Nearest to often: girona, targeting, degree, manure, kyiv, presentation, kinds, busy,
# Nearest to are: evident, segments, bancroft, hikaru, fabio, simply, marmara, missing,
# Nearest to however: implied, gottlieb, successive, asks, update, arises, topological, matters,
# Nearest to writers: bituminous, petrified, xiv, mchenry, venue, canaria, deaths, projekt,
# Nearest to ice: ac, assorted, bubblegum, dissolved, manipulated, dik, salzburg, disloyal,
# Nearest to derived: dignity, faisal, ece, novels, international, nm, reworking, becoming,
# Nearest to account: cellist, straightforward, bhutto, builds, capability, sup, trailers, chopper,
# Nearest to construction: played, wilfrid, cymru, hammerhead, demosthenes, sdi, puppeteer, numbers,
# Nearest to nobel: err, other, anyone, functionalists, aasen, nig, oued, publishing,
# Nearest to professional: main, gained, lusignan, thus, carved, lazio, transcriptions, upc,
# Nearest to grand: yellow, kentucky, enhanced, viscounts, macintoshes, excellent, tragedy, ambrosia,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.0103 0.4508 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9806 0.4483 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9514 0.4613 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9252 0.4443 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8428 0.4561 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8500 0.4484 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8586 0.4385 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8355 0.4427 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8412 0.4399 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8177 0.4473 sec/batch
# Nearest to between: unlike, sleep, material, achieved, massilia, receding, erdmann, iterative,
# Nearest to has: remembered, obtainable, radiation, donors, playfulness, floors, facts, everyman,
# Nearest to there: pay, unarable, afro, collect, ewen, wittelsbach, release, junction,
# Nearest to i: canadian, reductionist, remaining, romp, dreadnought, trio, install, ramp,
# Nearest to these: springer, permanently, tails, intra, extinct, thereby, wakefield, varied,
# Nearest to often: girona, targeting, crew, manure, invention, sheriff, kyiv, rabbits,
# Nearest to are: evident, bancroft, axioms, segments, postulates, hikaru, objectives, marmara,
# Nearest to however: implied, update, gottlieb, successive, topological, qualities, arises, disciples,
# Nearest to writers: awards, xiv, deaths, bituminous, petrified, adverse, waned, venue,
# Nearest to ice: ac, dissolved, assorted, manipulated, beaverbrook, bubblegum, salzburg, asmara,
# Nearest to derived: dignity, novels, nm, reworking, faisal, fishermen, pied, additional,
# Nearest to account: straightforward, cellist, bhutto, capability, builds, sup, columnist, jade,
# Nearest to construction: wilfrid, cymru, puppeteer, played, descendant, hammerhead, demosthenes, modis,
# Nearest to nobel: err, other, anyone, functionalists, aasen, oued, publishing, parkway,
# Nearest to professional: main, gained, transcriptions, upc, transferable, lazio, carved, lusignan,
# Nearest to grand: yellow, enhanced, kentucky, viscounts, tragedy, macintoshes, uncle, excellent,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8420 0.4479 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8098 0.4508 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7805 0.4465 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7724 0.4509 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8036 0.4710 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7439 0.4676 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7425 0.4588 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7625 0.4618 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7339 0.4512 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6878 0.4579 sec/batch
# Nearest to between: unlike, sleep, massilia, disavowed, bianca, receding, describes, feud,
# Nearest to has: obtainable, donors, playfulness, radiation, remembered, facts, damped, parr,
# Nearest to there: unarable, hereford, afro, ewen, wittelsbach, brewing, lecturers, pay,
# Nearest to i: canadian, romp, dreadnought, trio, reductionist, install, ramp, remaining,
# Nearest to these: springer, intra, tails, permanently, extinct, thereby, wakefield, cupboard,
# Nearest to often: girona, targeting, gherkin, sheriff, crew, navigational, manure, invention,
# Nearest to are: bancroft, axioms, segments, evident, marmara, postulates, bisecting, hikaru,
# Nearest to however: implied, update, successive, qualities, topological, gentiles, gottlieb, matters,
# Nearest to writers: awards, deaths, xiv, waned, bituminous, petrified, adverse, cont,
# Nearest to ice: manipulated, dissolved, ac, salzburg, bubblegum, andromache, beer, beaverbrook,
# Nearest to derived: dignity, reworking, novels, fishermen, nm, pied, faisal, additional,
# Nearest to account: straightforward, cellist, sup, bhutto, columnist, rationalisation, jade, builds,
# Nearest to construction: wilfrid, cymru, modis, puppeteer, demosthenes, sdi, hammerhead, descendant,
# Nearest to nobel: err, aasen, functionalists, publishing, baluchistan, vinyl, anyone, errico,
# Nearest to professional: lusignan, upc, main, transferable, barrels, patrick, transcriptions, lazio,
# Nearest to grand: yellow, kentucky, viscounts, enhanced, macintoshes, tragedy, uncle, ambrosia,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7070 0.4623 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7173 0.4516 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6258 0.4483 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6809 0.4507 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6515 0.4471 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6518 0.4504 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6213 0.3388 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5540 0.4557 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5388 0.4477 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4882 0.4597 sec/batch
# Nearest to between: unlike, massilia, sleep, disavowed, receding, bianca, achieved, describes,
# Nearest to has: obtainable, radiation, donors, playfulness, remembered, everyman, damped, facts,
# Nearest to there: unarable, hereford, ewen, lecturers, brewing, afro, positioned, theirs,
# Nearest to i: canadian, reductionist, romp, adjust, dreadnought, trio, remaining, el,
# Nearest to these: tails, intra, springer, description, permanently, wakefield, cupboard, thereby,
# Nearest to often: girona, navigational, smelter, sheriff, targeting, crew, ethiopian, gherkin,
# Nearest to are: segments, axioms, evident, bancroft, postulates, marmara, addiction, bisecting,
# Nearest to however: implied, update, topological, qualities, successive, arises, gentiles, disciples,
# Nearest to writers: awards, deaths, xiv, actors, projekt, waned, bituminous, koko,
# Nearest to ice: dissolved, manipulated, ac, salzburg, andromache, beer, beaverbrook, bubblegum,
# Nearest to derived: dignity, nm, reworking, capillaries, glidrose, comma, fishermen, additional,
# Nearest to account: straightforward, sup, cellist, remonstrance, bhutto, rationalisation, impart, jade,
# Nearest to construction: wilfrid, cymru, modis, puppeteer, biol, descendant, antigonus, iast,
# Nearest to nobel: err, eight, publishing, scott, scorsese, baluchistan, aasen, justus,
# Nearest to professional: lusignan, upc, main, patrick, transferable, transcriptions, narrative, supporter,
# Nearest to grand: yellow, kentucky, viscounts, macintoshes, uncle, ambrosia, tragedy, enhanced,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4808 0.4673 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4890 0.4435 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4255 0.4571 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5295 0.4423 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4555 0.4544 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4732 0.4420 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4290 0.4451 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3704 0.4361 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3899 0.4487 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3987 0.4464 sec/batch
# Nearest to between: unlike, massilia, achieved, receding, sleep, bianca, kelp, describes,
# Nearest to has: obtainable, donors, cracow, playfulness, damped, remembered, wo, everyman,
# Nearest to there: unarable, ewen, brewing, hereford, lecturers, kill, afro, loglan,
# Nearest to i: reductionist, remaining, bucky, plotinus, howerd, ruach, romp, el,
# Nearest to these: tails, intra, permanently, varied, rarely, description, wakefield, cupboard,
# Nearest to often: girona, smelter, navigational, implicit, kinds, rabbits, ethiopian, targeting,
# Nearest to are: segments, axioms, evident, bisecting, patched, marmara, postulates, transferring,
# Nearest to however: implied, disciples, successive, update, expelled, arises, elcano, qualities,
# Nearest to writers: deaths, awards, xiv, actors, waned, koko, screenplay, projekt,
# Nearest to ice: dissolved, ac, beer, manipulated, beaverbrook, salzburg, andromache, dik,
# Nearest to derived: capillaries, dignity, reworking, glidrose, additional, pied, comma, practical,
# Nearest to account: straightforward, remonstrance, rationalisation, dogger, jade, bhutto, cellist, sup,
# Nearest to construction: modis, cymru, wilfrid, iast, biol, descendant, puppeteer, hammerhead,
# Nearest to nobel: err, publishing, baluchistan, scott, aasen, scorsese, justus, icct,
# Nearest to professional: lusignan, upc, scheduling, main, graphemes, transferable, ethnologists, amphibole,
# Nearest to grand: kentucky, viscounts, yellow, macintoshes, uncle, ambrosia, tragedy, claris,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3966 0.4532 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3963 0.4483 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4476 0.4742 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3889 0.4613 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3798 0.4526 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4257 0.4491 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3474 0.4411 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3745 0.4416 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3671 0.4460 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3619 0.4426 sec/batch
# Nearest to between: unlike, massilia, describes, hallowell, flit, rutger, achieved, kelp,
# Nearest to has: obtainable, cracow, playfulness, donors, damped, floors, remembered, wo,
# Nearest to there: unarable, ewen, brewing, hereford, lecturers, loy, wittelsbach, afro,
# Nearest to i: plotinus, reductionist, howerd, remaining, bucky, el, ruach, dosomething,
# Nearest to these: tails, rarely, varied, intra, wakefield, permanently, description, coral,
# Nearest to often: girona, smelter, implicit, kinds, crates, rabbits, manure, terribly,
# Nearest to are: segments, marmara, axioms, evident, postulates, presently, patched, extending,
# Nearest to however: implied, expelled, disciples, matters, arises, elcano, gentiles, qualities,
# Nearest to writers: deaths, awards, poets, actors, xiv, waned, screenplay, andante,
# Nearest to ice: ac, beer, dissolved, andromache, manipulated, salzburg, solid, dik,
# Nearest to derived: capillaries, dignity, glidrose, additional, reworking, theologies, comma, pied,
# Nearest to account: straightforward, remonstrance, rationalisation, dogger, transsexualism, impart, hijacking, ccel,
# Nearest to construction: modis, iast, cymru, biol, wilfrid, pharmaceuticals, puppeteer, chromium,
# Nearest to nobel: err, publishing, laureate, baluchistan, scott, aasen, chemist, justus,
# Nearest to professional: lusignan, upc, graphemes, scheduling, ethnologists, transcriptions, lazio, narrative,
# Nearest to grand: kentucky, viscounts, yellow, macintoshes, uncle, claris, ambrosia, tragedy,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3642 0.4530 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3573 0.4454 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3165 0.4441 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3460 0.4451 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3630 0.4440 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3450 0.4478 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3638 0.4642 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3545 0.4491 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2960 0.4493 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2923 0.4364 sec/batch
# Nearest to between: massilia, kelp, adriatic, unlike, describes, flit, hallowell, receding,
# Nearest to has: obtainable, cracow, maximally, donors, floors, damped, insurrections, stabilize,
# Nearest to there: unarable, hereford, ewen, lecturers, brewing, positioned, afro, loy,
# Nearest to i: plotinus, dosomething, cellphone, howerd, reductionist, ruach, bucky, el,
# Nearest to these: tails, rarely, varied, intra, coral, vogt, wakefield, extinct,
# Nearest to often: smelter, girona, implicit, kinds, crates, rabbits, manure, angry,
# Nearest to are: segments, marmara, postulates, patched, presently, evident, helens, eukaryotes,
# Nearest to however: implied, expelled, matters, elcano, disciples, conservatorship, qualities, arises,
# Nearest to writers: awards, deaths, actors, poets, screenplay, xiv, andante, kitsch,
# Nearest to ice: solid, ac, beer, dissolved, cloud, manipulated, andromache, exhaled,
# Nearest to derived: capillaries, dignity, comma, pied, theologies, reworking, glidrose, additional,
# Nearest to account: straightforward, remonstrance, rationalisation, dogger, hijacking, impart, dialogs, capability,
# Nearest to construction: modis, cymru, pharmaceuticals, iast, biol, wilfrid, nicosian, descendant,
# Nearest to nobel: err, publishing, aasen, scorsese, scott, rusher, baluchistan, robbie,
# Nearest to professional: lusignan, upc, lazio, scheduling, ethnologists, graphemes, amphibole, transferable,
# Nearest to grand: viscounts, kentucky, yellow, claris, uncle, macintoshes, cowl, ambrosia,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3130 0.4546 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2870 0.4577 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3576 0.4517 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3815 0.4533 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3415 0.4551 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2549 0.4471 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2499 0.4557 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3021 0.4495 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2019 0.4450 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2478 0.4594 sec/batch
# Nearest to between: massilia, adriatic, flit, unlike, describes, swnts, benguela, disavowed,
# Nearest to has: obtainable, cracow, donors, insurrections, maximally, szechuan, playfulness, straddles,
# Nearest to there: unarable, ewen, hereford, brewing, loy, quintessentially, wittelsbach, afro,
# Nearest to i: plotinus, howerd, remaining, dosomething, bucky, ruach, cellphone, el,
# Nearest to these: tails, varied, rarely, coral, intra, democratization, permanently, wakefield,
# Nearest to often: girona, smelter, implicit, gherkin, kinds, crates, angry, manure,
# Nearest to are: marmara, segments, patched, postulates, axioms, interpreted, extending, presently,
# Nearest to however: implied, expelled, elcano, disciples, firebird, successive, matters, topological,
# Nearest to writers: deaths, awards, actors, poets, andante, politicians, xiv, fiction,
# Nearest to ice: solid, beer, ac, cloud, dissolved, salzburg, exhaled, andromache,
# Nearest to derived: capillaries, comma, theologies, reworking, dignity, pied, glidrose, additional,
# Nearest to account: straightforward, remonstrance, dogger, rationalisation, diagram, ccel, capability, impart,
# Nearest to construction: modis, iast, biol, pharmaceuticals, cymru, wilfrid, antigonus, hammerhead,
# Nearest to nobel: err, chemist, laureate, american, publishing, scott, aasen, bafta,
# Nearest to professional: upc, lusignan, patrick, pfa, supporter, lampoon, champions, lazio,
# Nearest to grand: viscounts, kentucky, yellow, claris, uncle, cowl, ambrosia, norfolk,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2709 0.4459 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2583 0.4504 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3282 0.2260 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2084 0.4495 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1828 0.4558 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1448 0.4479 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1497 0.4482 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1385 0.4484 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1575 0.4450 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1208 0.4466 sec/batch
# Nearest to between: massilia, adriatic, flit, kelp, unlike, achieved, rutger, swnts,
# Nearest to has: obtainable, maximally, everyman, cracow, damped, szechuan, playfulness, straddles,
# Nearest to there: unarable, ewen, hereford, loglan, brewing, than, loy, afro,
# Nearest to i: plotinus, remaining, el, bucky, dosomething, cellphone, howerd, you,
# Nearest to these: tails, varied, rarely, coral, intra, democratization, wakefield, description,
# Nearest to often: girona, smelter, gherkin, manure, terribly, crates, implicit, kinds,
# Nearest to are: marmara, segments, patched, eukaryotes, extending, bisecting, presently, postulates,
# Nearest to however: implied, expelled, firebird, disciples, heartbeat, update, elcano, strychnine,
# Nearest to writers: deaths, poets, actors, awards, politicians, andante, swaim, projekt,
# Nearest to ice: solid, dissolved, beer, exhaled, cloud, pack, andromache, ac,
# Nearest to derived: capillaries, comma, theologies, dignity, reworking, syriac, glidrose, pied,
# Nearest to account: straightforward, rationalisation, remonstrance, dogger, diagram, dialogs, ccel, codify,
# Nearest to construction: modis, cymru, biol, iast, wilfrid, pharmaceuticals, harbinger, descendant,
# Nearest to nobel: chemist, err, physiologist, publishing, aasen, laureate, justus, dontrelle,
# Nearest to professional: upc, lusignan, amphibole, supporter, pfa, sport, schools, lazio,
# Nearest to grand: viscounts, kentucky, yellow, claris, macintoshes, parrot, norfolk, uncle,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.1711 0.4390 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1569 0.4498 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1558 0.4504 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0696 0.4514 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1041 0.4512 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1071 0.4465 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.0949 0.4408 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1131 0.4623 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1918 0.4493 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1217 0.4376 sec/batch
# Nearest to between: massilia, unlike, achieved, adriatic, flit, represent, hallowell, benguela,
# Nearest to has: obtainable, damped, szechuan, maximally, donors, remembered, playfulness, similarities,
# Nearest to there: unarable, loy, than, loglan, lecturers, declensions, clavier, positioned,
# Nearest to i: plotinus, you, el, remaining, cellphone, howerd, jammed, trusted,
# Nearest to these: tails, varied, rarely, intra, coral, description, democratization, springer,
# Nearest to often: girona, smelter, manure, kinds, gherkin, terribly, angry, implicit,
# Nearest to are: patched, marmara, eukaryotes, postulates, bisecting, segments, interpreted, popularised,
# Nearest to however: implied, expelled, firebird, disciples, strychnine, update, sustenance, elcano,
# Nearest to writers: deaths, poets, actors, awards, politicians, andante, swaim, fiction,
# Nearest to ice: solid, beer, dissolved, pack, cloud, exhaled, andromache, dik,
# Nearest to derived: capillaries, theologies, comma, reworking, glidrose, dignity, dfs, syriac,
# Nearest to account: straightforward, rationalisation, dogger, remonstrance, ccel, dialogs, codify, hijacking,
# Nearest to construction: modis, pharmaceuticals, iast, cymru, biol, erdmann, wilfrid, hammerhead,
# Nearest to nobel: chemist, err, publishing, laureate, physiologist, aasen, rusher, loach,
# Nearest to professional: upc, amphibole, schools, sport, lusignan, pfa, supporter, lazio,
# Nearest to grand: viscounts, kentucky, claris, yellow, macintoshes, cowl, caucasian, parrot,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1103 0.4582 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1651 0.4471 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1244 0.4579 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.0921 0.4560 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1169 0.4493 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1144 0.4557 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1511 0.4547 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0680 0.4615 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1035 0.4533 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1080 0.4430 sec/batch
# Nearest to between: achieved, adriatic, massilia, unlike, flit, swnts, rutger, represent,
# Nearest to has: obtainable, szechuan, damped, donors, maximally, remembered, cracow, similarities,
# Nearest to there: unarable, lecturers, deinstitutionalization, hereford, clavier, than, loy, quintessentially,
# Nearest to i: plotinus, you, el, t, remaining, cellphone, subverted, dosomething,
# Nearest to these: tails, varied, rarely, intra, democratization, springer, description, coral,
# Nearest to often: girona, smelter, manure, implicit, crates, gherkin, angry, kinds,
# Nearest to are: patched, postulates, segments, marmara, axioms, alone, interpreted, awaited,
# Nearest to however: expelled, implied, disciples, firebird, heartbeat, topological, strokes, endometrial,
# Nearest to writers: deaths, poets, actors, awards, politicians, swaim, andante, fiction,
# Nearest to ice: solid, cloud, dissolved, pack, beer, exhaled, andromache, instantly,
# Nearest to derived: capillaries, theologies, comma, dignity, reworking, pied, glidrose, gottlob,
# Nearest to account: straightforward, rationalisation, ccel, dialogs, remonstrance, dogger, impart, diagram,
# Nearest to construction: modis, wilfrid, iast, cymru, pharmaceuticals, structuring, descendant, nicosian,
# Nearest to nobel: chemist, laureate, err, justus, publishing, physiologist, rusher, physiology,
# Nearest to professional: upc, sport, schools, amphibole, transcriptions, lusignan, ncaa, soccer,
# Nearest to grand: viscounts, claris, kentucky, yellow, macintoshes, sidewalk, moderns, caucasian,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1436 0.4640 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1303 0.4547 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1219 0.4470 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1539 0.4434 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1088 0.4350 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0669 0.4380 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1241 0.4352 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0702 0.4369 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1739 0.4445 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1698 0.4419 sec/batch
# Nearest to between: adriatic, massilia, achieved, unlike, swnts, rutger, disavowed, flit,
# Nearest to has: obtainable, donors, szechuan, maximally, cracow, everyman, similarities, remembered,
# Nearest to there: unarable, hereford, loy, deinstitutionalization, clavier, afro, latveria, than,
# Nearest to i: you, plotinus, t, el, cellphone, lick, my, remaining,
# Nearest to these: varied, rarely, tails, democratization, intra, description, coral, permanently,
# Nearest to often: girona, angry, smelter, crates, gherkin, manure, skyrocketed, terribly,
# Nearest to are: marmara, patched, quicksort, interpreted, timespan, awaited, alone, segments,
# Nearest to however: expelled, implied, firebird, strychnine, disciples, perpetuating, endometrial, emigr,
# Nearest to writers: deaths, actors, poets, awards, politicians, swaim, autodidacts, novelists,
# Nearest to ice: solid, dissolved, cloud, exhaled, beer, pack, salzburg, dik,
# Nearest to derived: capillaries, comma, theologies, reworking, glidrose, pied, dfs, dignity,
# Nearest to account: straightforward, rationalisation, ccel, remonstrance, symbolizes, dogger, harmonization, hijacking,
# Nearest to construction: modis, wilfrid, cymru, iast, descendant, pharmaceuticals, bev, harbinger,
# Nearest to nobel: chemist, laureate, physiology, geneticist, physiologist, dontrelle, aasen, err,
# Nearest to professional: upc, sport, lusignan, supporter, schools, transcriptions, pfa, soccer,
# Nearest to grand: viscounts, kentucky, claris, yellow, moderns, cowl, parrot, larwood,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1794 0.4456 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0649 0.4450 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0677 0.4394 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0740 0.4339 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9789 0.4412 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.0901 0.4405 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.0907 0.4380 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0837 0.4405 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1527 0.1082 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0637 0.4391 sec/batch
# Nearest to between: adriatic, achieved, massilia, swnts, unlike, flit, disavowed, rutger,
# Nearest to has: obtainable, maximally, szechuan, donors, straddles, similarities, everyman, melvin,
# Nearest to there: unarable, hereford, deinstitutionalization, loglan, than, quintessentially, vukovar, clavier,
# Nearest to i: you, t, my, el, plotinus, cellphone, remaining, dosomething,
# Nearest to these: rarely, varied, tails, intra, democratization, coral, permanently, wakefield,
# Nearest to often: girona, smelter, gherkin, angry, offshore, crates, degree, competing,
# Nearest to are: alone, patched, marmara, eukaryotes, segments, tuning, australians, awaited,
# Nearest to however: expelled, strychnine, firebird, implied, endometrial, kz, topological, disparaging,
# Nearest to writers: deaths, poets, actors, awards, politicians, autodidacts, swaim, novelists,
# Nearest to ice: solid, dissolved, cloud, exhaled, pack, salzburg, beer, racecourse,
# Nearest to derived: capillaries, comma, theologies, glidrose, reworking, dignity, gottlob, syriac,
# Nearest to account: straightforward, rationalisation, ccel, dialogs, impart, diagram, remonstrance, hijacking,
# Nearest to construction: modis, wilfrid, pharmaceuticals, iast, cymru, reals, bev, structuring,
# Nearest to nobel: laureate, chemist, physiology, physiologist, loach, prize, err, aasen,
# Nearest to professional: upc, sport, schools, transcriptions, pfa, ncaa, supporter, soccer,
# Nearest to grand: viscounts, kentucky, yellow, moderns, claris, cowl, larwood, caucasian,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.9917 0.4361 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0094 0.4329 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0046 0.4428 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.9663 0.4388 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0226 0.4367 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9650 0.4392 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0138 0.4402 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0332 0.4380 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0440 0.4433 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9510 0.4405 sec/batch
# Nearest to between: achieved, massilia, adriatic, unlike, swnts, rutger, disavowed, cathay,
# Nearest to has: obtainable, in, donors, maximally, szechuan, straddles, stabilize, similarities,
# Nearest to there: than, unarable, quintessentially, cidade, latveria, deinstitutionalization, weathered, loglan,
# Nearest to i: you, plotinus, t, el, my, cellphone, remaining, lick,
# Nearest to these: rarely, varied, coral, tails, democratization, permanently, intra, description,
# Nearest to often: girona, smelter, offshore, gherkin, angry, terribly, degree, kinds,
# Nearest to are: patched, alone, marmara, eukaryotes, segments, bisecting, some, addiction,
# Nearest to however: expelled, firebird, implied, strychnine, heartbeat, rejoining, disciples, kz,
# Nearest to writers: deaths, poets, actors, awards, autodidacts, politicians, swaim, novelists,
# Nearest to ice: solid, dissolved, pack, exhaled, salzburg, cloud, dik, racecourse,
# Nearest to derived: capillaries, theologies, comma, reworking, glidrose, dignity, syriac, banknotes,
# Nearest to account: straightforward, rationalisation, remonstrance, hijacking, dialogs, ccel, codify, harmonization,
# Nearest to construction: modis, pharmaceuticals, wilfrid, iast, cymru, descendant, nicosian, erdmann,
# Nearest to nobel: chemist, laureate, physiology, physiologist, err, aasen, loach, dontrelle,
# Nearest to professional: sport, schools, upc, amphibole, ncaa, soccer, pfa, transcriptions,
# Nearest to grand: viscounts, moderns, kentucky, cowl, claris, yellow, macintoshes, larwood,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9427 0.4513 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9723 0.4595 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9252 0.4640 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.9761 0.4523 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.9926 0.4401 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9722 0.4480 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.9961 0.4464 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0485 0.4526 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.9977 0.4567 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9713 0.4572 sec/batch
# Nearest to between: achieved, adriatic, unlike, massilia, flit, represent, swnts, hyperactive,
# Nearest to has: obtainable, maximally, szechuan, donors, in, similarities, remembered, damped,
# Nearest to there: than, unarable, quintessentially, latveria, clavier, declensions, deinstitutionalization, cidade,
# Nearest to i: you, t, my, plotinus, el, cellphone, lp, lick,
# Nearest to these: varied, rarely, coral, tails, democratization, intra, description, springer,
# Nearest to often: girona, smelter, offshore, angry, gherkin, terribly, usually, invention,
# Nearest to are: patched, alone, schematics, eukaryotes, some, bisecting, cosines, interpreted,
# Nearest to however: expelled, firebird, strychnine, implied, disciples, endometrial, renomination, perpetuating,
# Nearest to writers: deaths, poets, actors, awards, novelists, autodidacts, swaim, fiction,
# Nearest to ice: solid, dissolved, exhaled, cloud, pack, salzburg, astbury, beer,
# Nearest to derived: theologies, capillaries, comma, reworking, glidrose, dignity, gottlob, syriac,
# Nearest to account: straightforward, rationalisation, ccel, hijacking, codify, dialogs, remonstrance, transsexualism,
# Nearest to construction: modis, pharmaceuticals, wilfrid, iast, reals, descendant, cymru, nicosian,
# Nearest to nobel: laureate, chemist, physiologist, prize, physiology, aasen, geneticist, loach,
# Nearest to professional: schools, upc, sport, ncaa, amphibole, transcriptions, pfa, soccer,
# Nearest to grand: viscounts, moderns, yellow, kentucky, cowl, larwood, claris, caucasian,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9652 0.4512 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0029 0.4415 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0412 0.4444 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9378 0.4500 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0002 0.4640 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.9937 0.4585 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.9819 0.4448 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0251 0.4491 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0056 0.4505 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0114 0.4549 sec/batch
# Nearest to between: adriatic, achieved, massilia, unlike, swnts, flit, hallowell, cathay,
# Nearest to has: obtainable, maximally, szechuan, in, remembered, contaminating, stabilize, consequential,
# Nearest to there: latveria, than, quintessentially, unarable, cidade, declensions, deinstitutionalization, clavier,
# Nearest to i: you, my, t, plotinus, el, cellphone, lp, didn,
# Nearest to these: varied, rarely, coral, tails, intra, democratization, wakefield, permanently,
# Nearest to often: girona, smelter, angry, gherkin, offshore, usually, crates, competing,
# Nearest to are: marmara, alone, patched, segments, bisecting, some, glossary, schematics,
# Nearest to however: expelled, disciples, elcano, implied, firebird, renomination, factional, strychnine,
# Nearest to writers: deaths, poets, actors, awards, novelists, autodidacts, swaim, politicians,
# Nearest to ice: dissolved, solid, exhaled, paddock, salzburg, beaverbrook, cloud, asmara,
# Nearest to derived: capillaries, theologies, comma, glidrose, reworking, syriac, dignity, pied,
# Nearest to account: straightforward, ccel, rationalisation, hijacking, codify, dialogs, harmonization, remonstrance,
# Nearest to construction: modis, wilfrid, cymru, descendant, iast, reals, nicosian, pharmaceuticals,
# Nearest to nobel: laureate, chemist, physiology, prize, justus, physiologist, geneticist, aasen,
# Nearest to professional: schools, upc, transcriptions, sport, ethnologists, ncaa, varsity, amphibole,
# Nearest to grand: viscounts, moderns, yellow, cowl, larwood, claris, kentucky, sidewalk,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.9830 0.4546 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9311 0.4646 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9825 0.4467 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0159 0.4523 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0086 0.4423 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0711 0.4411 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0548 0.4520 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9837 0.4447 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9455 0.4403 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.9847 0.4362 sec/batch
# Nearest to between: adriatic, unlike, swnts, achieved, provers, cathay, massilia, iterative,
# Nearest to has: obtainable, szechuan, maximally, in, melvin, infused, stabilize, consequential,
# Nearest to there: than, quintessentially, deinstitutionalization, unarable, clavier, latveria, declensions, cidade,
# Nearest to i: you, t, my, plotinus, el, want, lp, cellphone,
# Nearest to these: varied, rarely, coral, tails, democratization, extinct, attitudes, description,
# Nearest to often: girona, smelter, gherkin, angry, offshore, usually, competing, crates,
# Nearest to are: marmara, patched, alone, bisecting, families, schematics, inmarsat, some,
# Nearest to however: expelled, firebird, strychnine, renomination, implied, kz, gutnish, disciples,
# Nearest to writers: deaths, poets, actors, novelists, autodidacts, awards, swaim, politicians,
# Nearest to ice: dissolved, solid, salzburg, asmara, exhaled, dykes, disloyal, dik,
# Nearest to derived: theologies, capillaries, comma, glidrose, reworking, syriac, dignity, pied,
# Nearest to account: straightforward, ccel, rationalisation, hijacking, turrets, codify, diagram, dogger,
# Nearest to construction: modis, iast, wilfrid, descendant, reals, cymru, ambiente, erdmann,
# Nearest to nobel: laureate, chemist, prize, physiology, aasen, geneticist, physiologist, errico,
# Nearest to professional: schools, transcriptions, sport, upc, supporter, pfa, soccer, businessmen,
# Nearest to grand: viscounts, moderns, cowl, larwood, yellow, sidewalk, masonic, kentucky,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9312 0.4522 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9472 0.4452 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9744 0.4408 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9728 0.4459 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.9984 0.4517 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9787 0.4444 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9488 0.4394 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.8866 0.4677 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9444 0.4573 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9328 0.4576 sec/batch
# Nearest to between: adriatic, massilia, swnts, flit, unlike, cathay, textural, achieved,
# Nearest to has: obtainable, maximally, contaminating, similarities, in, infused, szechuan, remembered,
# Nearest to there: than, deinstitutionalization, latveria, unarable, vantaa, quintessentially, lecturers, declensions,
# Nearest to i: you, my, t, plotinus, want, el, didn, theobald,
# Nearest to these: varied, rarely, coral, extinct, democratization, tails, intra, uninteresting,
# Nearest to often: girona, smelter, gherkin, degree, usually, offshore, angry, as,
# Nearest to are: patched, marmara, some, alone, addiction, schematics, families, axioms,
# Nearest to however: firebird, expelled, strychnine, implied, endometrial, gutnish, renomination, kz,
# Nearest to writers: deaths, poets, actors, novelists, autodidacts, awards, swaim, politicians,
# Nearest to ice: solid, salzburg, dissolved, asmara, dykes, scottish, exhaled, mcgregor,
# Nearest to derived: capillaries, theologies, comma, glidrose, dignity, syriac, reworking, tetrahedron,
# Nearest to account: straightforward, ccel, rationalisation, hijacking, turrets, codify, conveyed, lucidity,
# Nearest to construction: modis, wilfrid, iast, reals, greenhouses, cymru, nicosian, pharmaceuticals,
# Nearest to nobel: laureate, chemist, prize, physiology, physiologist, justus, aasen, geneticist,
# Nearest to professional: transcriptions, upc, schools, sport, soccer, ethnologists, supporter, businessmen,
# Nearest to grand: viscounts, moderns, yellow, cowl, larwood, sidewalk, amazingly, caucasian,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.8931 0.4607 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8709 0.4578 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9229 0.4551 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9399 0.4600 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9650 0.4545 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.8932 0.4477 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8218 0.4486 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.8848 0.4543 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8322 0.4465 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.8881 0.4492 sec/batch
# Nearest to between: adriatic, unlike, iterative, swnts, blur, hyperactive, massilia, flit,
# Nearest to has: obtainable, maximally, in, contaminating, infused, tibeto, szechuan, president,
# Nearest to there: than, deinstitutionalization, latveria, cidade, declensions, unarable, vantaa, quintessentially,
# Nearest to i: you, t, my, plotinus, want, el, lp, cellphone,
# Nearest to these: varied, rarely, coral, democratization, extinct, tails, wakefield, cupboard,
# Nearest to often: girona, smelter, offshore, usually, gherkin, as, degree, competing,
# Nearest to are: patched, some, alone, they, addiction, families, vegetarians, schematics,
# Nearest to however: firebird, expelled, factional, strokes, strychnine, carmelites, disciples, perpetuating,
# Nearest to writers: deaths, poets, actors, novelists, autodidacts, awards, swaim, politicians,
# Nearest to ice: solid, dissolved, exhaled, asmara, salzburg, vectors, bubblegum, scottish,
# Nearest to derived: capillaries, theologies, glidrose, dignity, reworking, comma, syriac, tetrahedron,
# Nearest to account: ccel, straightforward, hijacking, turrets, rationalisation, rotherhithe, dorpat, conveyed,
# Nearest to construction: modis, wilfrid, greenhouses, reals, pharmaceuticals, descendant, jodie, ambiente,
# Nearest to nobel: laureate, chemist, prize, physiologist, physiology, aasen, errico, geneticist,
# Nearest to professional: schools, transcriptions, sport, upc, ncaa, skaters, amphibole, supporter,
# Nearest to grand: viscounts, moderns, larwood, sidewalk, amazingly, yellow, cowl, masonic,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.8924 0.4625 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.8904 0.4610 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.8902 0.4489 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9324 0.4498 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9873 0.4435 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8561 0.4547 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9065 0.4499 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9107 0.4559 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9535 0.4459 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9015 0.4493 sec/batch
# Nearest to between: adriatic, measured, hyperactive, swnts, iterative, unlike, achieved, massilia,
# Nearest to has: obtainable, in, maximally, president, consequential, roosevelt, tibeto, melvin,
# Nearest to there: than, deinstitutionalization, clavier, declensions, quintessentially, latveria, omim, cidade,
# Nearest to i: you, t, my, want, el, plotinus, lp, cellphone,
# Nearest to these: varied, rarely, coral, democratization, wakefield, tails, attitudes, extinct,
# Nearest to often: girona, smelter, usually, gherkin, offshore, competing, degree, as,
# Nearest to are: alone, some, patched, families, have, they, inmarsat, disclaimers,
# Nearest to however: expelled, firebird, gutnish, kz, disciples, factional, paternal, implied,
# Nearest to writers: deaths, poets, novelists, actors, autodidacts, awards, swaim, fiction,
# Nearest to ice: dissolved, solid, bubblegum, asmara, exhaled, salzburg, beaverbrook, vectors,
# Nearest to derived: capillaries, glidrose, theologies, dignity, reworking, comma, gottlob, tetrahedron,
# Nearest to account: ccel, straightforward, hijacking, rationalisation, turrets, dorpat, harmonization, parsimony,
# Nearest to construction: modis, wilfrid, greenhouses, iast, reals, pharmaceuticals, jodie, descendant,
# Nearest to nobel: laureate, chemist, prize, physiology, physiologist, geneticist, justus, emil,
# Nearest to professional: transcriptions, sport, schools, upc, clubs, cornerbacks, varsity, ethnologists,
# Nearest to grand: viscounts, moderns, sidewalk, yellow, amazingly, larwood, masonic, cowl,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9244 0.4540 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.8795 0.4512 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9138 0.4518 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9458 0.4549 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9545 0.4576 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9295 0.4577 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9111 0.4543 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.8818 0.4538 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.8802 0.4573 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9412 0.4455 sec/batch
# Nearest to between: adriatic, unlike, massilia, swnts, iterative, unforgiven, measured, achieved,
# Nearest to has: obtainable, stabilize, in, tibeto, contaminating, that, maximally, president,
# Nearest to there: than, deinstitutionalization, clavier, latveria, cidade, declensions, quintessentially, larger,
# Nearest to i: you, t, my, want, el, lp, plotinus, cellphone,
# Nearest to these: varied, rarely, coral, democratization, attitudes, extinct, tails, card,
# Nearest to often: girona, smelter, usually, gherkin, angry, competing, as, offshore,
# ...
# Nearest to professional: transcriptions, sport, cornerbacks, ncaa, upc, lazio, soccer, practise,
# Nearest to grand: viscounts, moderns, sidewalk, cowl, yellow, masonic, amazingly, larwood,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.8667 0.4417 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.8837 0.4592 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.7561 0.4553 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.8658 0.4452 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.7676 0.4463 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.8095 0.4413 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.8320 0.4454 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.8719 0.4443 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.8146 0.4354 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.8281 0.4509 sec/batch
# Nearest to between: adriatic, unlike, hyperactive, measured, blur, unforgiven, iterative, provers,
# Nearest to has: in, that, obtainable, tibeto, amyotrophic, melvin, maximally, contaminating,
# Nearest to there: than, deinstitutionalization, some, clavier, latveria, declensions, larger, lecturers,
# Nearest to i: you, t, my, want, lp, el, cellphone, miao,
# Nearest to these: varied, rarely, coral, attitudes, democratization, wakefield, uninteresting, hamburgers,
# Nearest to often: as, girona, usually, smelter, offshore, competing, gherkin, degree,
# Nearest to are: some, alone, have, they, of, patched, or, other,
# Nearest to however: at, expelled, firebird, strychnine, strokes, gutnish, gin, paternal,
# Nearest to writers: poets, novelists, autodidacts, deaths, actors, swaim, awards, fiction,
# Nearest to ice: dissolved, solid, exhaled, scottish, asmara, dykes, vectors, itinerarium,
# Nearest to derived: capillaries, glidrose, dignity, theologies, reworking, banknotes, syriac, cognate,
# Nearest to account: ccel, straightforward, hijacking, turrets, terrell, dorpat, parsimony, rotherhithe,
# Nearest to construction: modis, reals, wilfrid, erdmann, greenhouses, descendant, iast, ambiente,
# Nearest to nobel: prize, chemist, laureate, physiologist, physiology, derivations, geneticist, cartan,
# Nearest to professional: transcriptions, cornerbacks, varsity, sport, skaters, ncaa, ethnologists, lazio,
# Nearest to grand: viscounts, moderns, sidewalk, amazingly, cowl, masonic, yellow, disseminate,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.9277 0.4452 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.8267 0.4403 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.8179 0.4575 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.8455 0.4456 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.8666 0.4459 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.8676 0.4419 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.8820 0.4527 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.8533 0.4456 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.8564 0.4392 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9322 0.4399 sec/batch
# Nearest to between: adriatic, unforgiven, measured, hyperactive, among, iterative, swnts, textural,
# Nearest to has: in, that, obtainable, stabilize, tibeto, melvin, contaminating, amyotrophic,
# Nearest to there: than, deinstitutionalization, some, clavier, latveria, declensions, lecturers, vantaa,
# Nearest to i: t, you, my, want, el, lp, miao, plotinus,
# Nearest to these: varied, rarely, attitudes, coral, democratization, aurangabad, wakefield, uninteresting,
# Nearest to often: as, girona, usually, gherkin, smelter, offshore, clashing, competing,
# Nearest to are: have, some, alone, they, of, also, other, patched,
# Nearest to however: expelled, at, firebird, kz, strokes, gutnish, paternal, gin,
# Nearest to writers: poets, novelists, deaths, autodidacts, actors, swaim, awards, natives,
# Nearest to ice: exhaled, dissolved, solid, vectors, asmara, scottish, melting, dykes,
# Nearest to derived: dignity, capillaries, glidrose, theologies, reworking, syriac, hif, samael,
# Nearest to account: ccel, straightforward, hijacking, terrell, dorpat, turrets, parsimony, conveyed,
# Nearest to construction: modis, reals, erdmann, greenhouses, descendant, wilfrid, rochester, ambiente,
# Nearest to nobel: prize, chemist, laureate, physiology, physiologist, derivations, suicides, geneticist,
# Nearest to professional: transcriptions, cornerbacks, very, clubs, sport, skaters, varsity, ncaa,
# Nearest to grand: moderns, viscounts, sidewalk, masonic, amazingly, cowl, complimentary, disseminate,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.8400 0.4519 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.8663 0.4485 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.8795 0.4423 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.8038 0.4536 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.8401 0.4413 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.8922 0.4464 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.8841 0.4444 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 3.9778 0.4487 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 3.8943 0.4574 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 3.9182 0.4509 sec/batch
# Nearest to between: adriatic, unforgiven, among, disavowed, provers, bianca, unlike, lewiec,
# Nearest to has: in, that, obtainable, tibeto, contaminating, melvin, stabilize, it,
# Nearest to there: than, deinstitutionalization, some, latveria, clavier, vantaa, tees, sieves,
# Nearest to i: t, you, want, my, lp, cellphone, el, miao,
# Nearest to these: varied, attitudes, rarely, coral, fornication, punished, democratization, vogt,
# Nearest to often: as, usually, girona, gherkin, and, smelter, competing, offshore,
# Nearest to are: some, have, alone, they, also, patched, other, or,
# Nearest to however: expelled, strokes, renomination, but, at, firebird, paternal, factional,
# Nearest to writers: deaths, novelists, poets, autodidacts, actors, swaim, awards, politicians,
# Nearest to ice: solid, dissolved, scottish, exhaled, asmara, skating, dykes, itinerarium,
# Nearest to derived: capillaries, glidrose, dignity, theologies, reworking, hif, banknotes, syriac,
# Nearest to account: ccel, straightforward, dorpat, hijacking, turrets, conveyed, terrell, rotherhithe,
# Nearest to construction: modis, descendant, reals, wilfrid, erdmann, greenhouses, ambiente, jodie,
# Nearest to nobel: prize, laureate, chemist, physiology, physiologist, microbiologist, errico, bafta,
# Nearest to professional: transcriptions, cornerbacks, practise, skaters, ethnologists, ncaa, harpersanfrancisco, businessmen,
# Nearest to grand: moderns, viscounts, masonic, sidewalk, amazingly, cowl, larwood, complimentary,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.8222 0.4413 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.7537 0.4474 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.8746 0.4422 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.7686 0.4470 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.8652 0.4446 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.8590 0.4491 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.8490 0.4516 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9167 0.2211 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.8121 0.4466 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.7964 0.4405 sec/batch
# Nearest to between: adriatic, among, unforgiven, bianca, provers, iterative, disavowed, measured,
# Nearest to has: in, that, stabilize, obtainable, tibeto, melvin, contaminating, it,
# Nearest to there: than, deinstitutionalization, some, latveria, vantaa, sieves, clavier, lecturers,
# Nearest to i: t, want, you, my, lp, breakdown, cellphone, miao,
# Nearest to these: varied, attitudes, rarely, aurangabad, coral, democratization, fornication, wakefield,
# Nearest to often: as, usually, girona, and, competing, gherkin, smelter, degree,
# Nearest to are: some, have, alone, other, also, they, or, of,
# Nearest to however: at, gutnish, paternal, but, kz, gin, been, strychnine,
# Nearest to writers: deaths, poets, autodidacts, novelists, actors, swaim, politicians, awards,
# Nearest to ice: dissolved, solid, scottish, exhaled, asmara, dykes, lemy, skating,
# Nearest to derived: capillaries, dignity, glidrose, theologies, hif, reworking, syriac, banknotes,
# Nearest to account: ccel, straightforward, hijacking, terrell, dorpat, conveyed, turrets, parsimony,
# Nearest to construction: modis, reals, descendant, wilfrid, erdmann, greenhouses, iast, pharmaceuticals,
# Nearest to nobel: prize, laureate, chemist, physiology, physiologist, microbiologist, derivations, chemists,
# Nearest to professional: transcriptions, cornerbacks, practise, skaters, wrestler, ethnologists, ncaa, harpersanfrancisco,
# Nearest to grand: moderns, viscounts, sidewalk, masonic, amazingly, larwood, cowl, yellow,
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8262 0.4416 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.7962 0.4359 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.7977 0.4433 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.8164 0.4647 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.7828 0.4490 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.8372 0.4332 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.8081 0.4342 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.8560 0.4403 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.7530 0.4330 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.7971 0.4435 sec/batch
# Nearest to between: among, adriatic, unlike, bianca, unforgiven, lewiec, fruitarianism, cathay,
# Nearest to has: in, obtainable, that, been, stabilize, it, united, tibeto,
# Nearest to there: than, some, deinstitutionalization, latveria, larger, are, vantaa, cidre,
# Nearest to i: t, you, want, my, lp, breakdown, cellphone, miao,
# Nearest to these: varied, attitudes, rarely, coral, aurangabad, wakefield, democratization, hamburgers,
# Nearest to often: as, usually, girona, and, competing, are, affectional, degree,
# Nearest to are: some, have, they, alone, other, of, is, also,
# Nearest to however: at, but, carmelites, been, feared, renomination, paternal, factional,
# Nearest to writers: poets, deaths, autodidacts, novelists, actors, swaim, awards, politicians,
# Nearest to ice: dissolved, solid, scottish, hockey, vectors, asmara, exhaled, lemy,
# Nearest to derived: dignity, capillaries, glidrose, theologies, reworking, hif, samael, banknotes,
# Nearest to account: ccel, straightforward, dorpat, hijacking, terrell, rotherhithe, conveyed, turrets,
# Nearest to construction: modis, greenhouses, reals, descendant, ambiente, pharmaceuticals, bev, wilfrid,
# Nearest to nobel: prize, laureate, chemist, physiology, physiologist, microbiologist, physics, suicides,
# Nearest to professional: transcriptions, cornerbacks, practise, ethnologists, very, sport, clubs, ncaa,
# Nearest to grand: moderns, viscounts, amazingly, masonic, sidewalk, cowl, disseminate, complimentary,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.7637 0.4450 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.7230 0.4356 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.7649 0.4396 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.8319 0.4404 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8085 0.4343 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.7769 0.4436 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.8520 0.4353 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8305 0.4404 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8207 0.4406 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.7969 0.4332 sec/batch
# Nearest to between: disavowed, blur, unlike, bianca, same, unforgiven, iterative, adriatic,
# Nearest to has: in, that, it, obtainable, been, stabilize, tibeto, however,
# Nearest to there: than, some, are, deinstitutionalization, clavier, latveria, from, cidre,
# Nearest to i: t, you, want, my, lp, cellphone, didn, miao,
# Nearest to these: varied, attitudes, rarely, wakefield, coral, democratization, hamburgers, punished,
# Nearest to often: as, usually, girona, competing, and, are, smelter, wards,
# Nearest to are: some, have, alone, other, they, or, of, is,
# Nearest to however: at, but, been, carmelites, is, feared, paternal, endometrial,
# Nearest to writers: poets, deaths, autodidacts, novelists, swaim, actors, awards, politicians,
# Nearest to ice: dissolved, solid, vectors, itinerarium, scottish, asmara, exhaled, lemy,
# Nearest to derived: dignity, glidrose, capillaries, theologies, heysel, reworking, banknotes, hif,
# Nearest to account: ccel, straightforward, dorpat, conveyed, terrell, harmonization, turrets, hijacking,
# Nearest to construction: modis, reals, greenhouses, bev, descendant, erdmann, ambiente, wilfrid,
# Nearest to nobel: prize, laureate, chemist, physiologist, physiology, microbiologist, justus, derivations,
# Nearest to professional: transcriptions, cornerbacks, practise, ethnologists, very, skaters, harpersanfrancisco, germantown,
# Nearest to grand: viscounts, moderns, masonic, sidewalk, amazingly, cowl, complimentary, larwood,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.8239 0.4408 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.8679 0.4379 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.7906 0.4370 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.7860 0.4486 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.8068 0.4361 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.8760 0.4370 sec/batch
# Epoch 7/10 Iteration: 30700 Avg. Training loss: 3.8349 0.4457 sec/batch
# Epoch 7/10 Iteration: 30800 Avg. Training loss: 3.7986 0.4325 sec/batch
# Epoch 7/10 Iteration: 30900 Avg. Training loss: 3.8284 0.4358 sec/batch
# Epoch 7/10 Iteration: 31000 Avg. Training loss: 3.7928 0.4365 sec/batch
# Nearest to between: adriatic, among, in, bianca, same, unforgiven, bermudez, and,
# Nearest to has: in, that, it, stabilize, been, tibeto, however, the,
# Nearest to there: than, some, are, deinstitutionalization, latveria, clavier, from, jirga,
# Nearest to i: t, you, want, my, lp, didn, cellphone, what,
# Nearest to these: varied, attitudes, coral, rarely, wakefield, somewhat, democratization, punished,
# Nearest to often: as, usually, girona, competing, are, and, yoshi, smelter,
# Nearest to are: have, some, they, alone, other, in, of, is,
# Nearest to however: in, at, been, but, has, is, paternal, factional,
# Nearest to writers: poets, novelists, autodidacts, deaths, actors, swaim, awards, politicians,
# Nearest to ice: dissolved, lemy, solid, itinerarium, asmara, vectors, scottish, hockey,
# Nearest to derived: capillaries, dignity, glidrose, theologies, hif, banknotes, syriac, beltane,
# Nearest to account: ccel, straightforward, accounts, conveyed, turrets, dorpat, harmonization, rotherhithe,
# Nearest to construction: modis, reals, descendant, erdmann, greenhouses, ambiente, wilfrid, osu,
# Nearest to nobel: prize, laureate, chemist, physiologist, physiology, microbiologist, awarded, justus,
# Nearest to professional: transcriptions, cornerbacks, clubs, very, practise, skaters, germantown, ethnologists,
# Nearest to grand: moderns, viscounts, masonic, sidewalk, amazingly, cowl, complimentary, disseminate,
# Epoch 7/10 Iteration: 31100 Avg. Training loss: 3.7937 0.4376 sec/batch
# Epoch 7/10 Iteration: 31200 Avg. Training loss: 3.8549 0.4407 sec/batch
# Epoch 7/10 Iteration: 31300 Avg. Training loss: 3.8035 0.4497 sec/batch
# Epoch 7/10 Iteration: 31400 Avg. Training loss: 3.9044 0.4398 sec/batch
# Epoch 7/10 Iteration: 31500 Avg. Training loss: 3.8936 0.4404 sec/batch
# Epoch 7/10 Iteration: 31600 Avg. Training loss: 3.8839 0.4447 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
